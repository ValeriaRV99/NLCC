# %% [markdown]
# # Building Nonlinear Core Correction from PStudio AE Data
#
# Changing the hight of the NLCC from AE core density

# %%
import sys, os
sys.path.append(os.path.abspath('/projectsn/mp1009_1/Valeria/NLPP_high_temperature/PStudio/'))
import numpy as np
import matplotlib.pyplot as plt
from dftpy.field import DirectField
from dftpy.formats import io
from scipy.interpolate import interp1d
from scipy.optimize import root_scalar
from pstudio.oncvpsp_routines.oncvpsp import hartree
from dftpy.optimization import Optimization
from dftpy.ions import Ions
from dftpy.grid import DirectGrid
from dftpy.math_utils import ecut2nr
from ase import Atoms
from dftpy.math_utils import ecut2nr
from dftpy.constants import Units

# %% [markdown]
# ## PStudio

# %%
from math import pi
from pstudio import AE, set_output
set_output('-')
ae = AE('Ag', config='[Kr] 4d10 5s1', xcname='LDA-py')
ae.run()
r = ae.rgd.r
rho = ae.rho
rc = 1.7 #/ Units.Bohr  # core matching radius (can be tuned)

def split_function(r, rc):
    fg = 0.5 * (1 + np.cos(-(r - rc) / rc * np.pi))
    fl = 0.5 * (1 - np.cos(-(r - rc) / rc * np.pi))
    f_g = np.ones_like(r)
    f_g[r < rc] = fg[r < rc]
    f_l = np.ones_like(r)
    f_l[r > 0] = fl[r > 0]
    f_l[r > rc] = 0.0
    return f_l, f_g

l, g = split_function(r, rc)
rho_core_array = (rho * l) * 4 * pi * r**2
# Out:
# scalar relativistic atomic calculation for Ag (Silver, Z=47)
# configuration: 1s2 2s2 2p6 3s2 3p6 3d10 4s2 4p6 4d10 5s1, 47 electrons
# exchange-correlation: LDA-python
# 2001 radial gridpoints in [1e-05,100]
#
# Converged in 52 iterations
#
# Energy contributions:
# ------------------------------------------------------------------------
# Kinetic:    +5516.245782 Ha    +150104.693253 eV
# Ionic:     -12842.849803 Ha    -349471.743327 eV
# Hartree:    +2159.595659 Ha    +58765.591076 eV
# XC:          -144.124492 Ha     -3921.827175 eV
# ------------------------------------------------------------------------
# Total:      -5311.132659 Ha    -144523.280888 eV
#
# state      eigenvalue      eigenvalue        rmax
# ------------------------------------------------------------------------
# 1s2       -929.721610 Ha -25299.013595 eV    0.020
# 2s2       -136.922654 Ha -3725.855195 eV    0.114
# 2p6       -122.897115 Ha -3344.200832 eV    0.091
# 3s2        -25.084394 Ha  -682.581132 eV    0.333
# 3p6        -20.477576 Ha  -557.223238 eV    0.327
# 3d10       -13.189540 Ha  -358.905652 eV    0.274
# 4s2         -3.494046 Ha   -95.077825 eV    0.820
# 4p6         -2.155979 Ha   -58.667189 eV    0.875
# 4d10        -0.281568 Ha    -7.661863 eV    1.036
# 5s1         -0.173446 Ha    -4.719698 eV    2.475

# %%
plt.plot(r, rho * 4 * pi * r**2, label='Total AE ρ(r)')
plt.plot(r,rho*g*4*pi*r**2,label="greater")

plt.plot(r, rho_core_array, label='Core ρ_core(r)', linestyle='--')
plt.axvline(rc, color='k', linestyle=':', label='rc')
plt.xlabel("r (a.u.)")
plt.ylabel("ρ(r)")
plt.legend()
plt.grid(True)
plt.title("AE and Smoothed Core Density")
plt.xlim(0,3)
plt.show()

# %% [markdown]
# ##  Build Nonlinear Core Correction (NLCC) Field

# %%
import numpy as np
from scipy.optimize import root
from scipy.interpolate import interp1d
from scipy.misc import derivative

def construct_core_density_smooth(r, r_core, rho_core_array, r_pc):
    rho_interp = interp1d(r, rho_core_array, kind='cubic', bounds_error=False, fill_value=0.0)
    f0 = rho_interp(r_pc)
    f0_prime = derivative(rho_interp, r_pc, dx=1e-4)

    def equations(params):
        b, c = params
        a = np.log(f0 / r_pc**2) - b * r_pc**2 - c * r_pc**4
        term1 = 2 * r_pc * np.exp(a + b * r_pc**2 + c * r_pc**4)
        term2 = r_pc**2 * np.exp(a + b * r_pc**2 + c * r_pc**4) * (2 * b * r_pc + 4 * c * r_pc**3)
        dcore = term1 + term2
        return [dcore - f0_prime, ] 
        
    def solve_with_c(c_fixed):
        def single_eq(b):
            return equations([b, c_fixed])[0]
        b_sol = root(single_eq, 0.1).x[0]
        return b_sol, c_fixed

    c_try = 0.0
    b_fit, c_fit = solve_with_c(c_try)
    a_fit = np.log(f0 / r_pc**2) - b_fit * r_pc**2 - c_fit * r_pc**4

    rhoc = np.zeros_like(r_core)
    inner_mask = r_core < r_pc
    outer_mask = ~inner_mask
    rhoc[inner_mask] = r_core[inner_mask]**2 * np.exp(a_fit + b_fit * r_core[inner_mask]**2 + c_fit * r_core[inner_mask]**4)
    rhoc[outer_mask] = rho_interp(r_core[outer_mask])
    return rhoc

# %%
from dftpy.functional import LocalPseudo, Functional, TotalFunctional

# %%
ions_ag, rho_target_ag, _ = io.read_all('/projectsn/mp1009_1/Valeria/NLPP/All_elements/rho_ref/rho_Ag_gbrv.xsf')
grid = rho_target_ag.grid

path_ngbrv = '/projectsn/mp1009_1/Valeria/NLPP/NPP_0.2/'
PP_list_ngbrv_ag = {'Ag': path_ngbrv + '/Ag_gbrv_new.psp8'}

path_gbrv = '/projectsn/mp1009_1/Valeria/NLPP/PP/'
PP_list_gbrv_ag = {'Ag': path_gbrv+'ag_lda_v1.4.uspp.F.UPF'}

nr = ecut2nr(ecut=600, lattice=ions_ag.cell)
grid = DirectGrid(lattice=ions_ag.cell, nr=nr)

pseudo_gbrv_ag = LocalPseudo(grid = grid, ions=ions_ag, PP_list=PP_list_gbrv_ag)
pseudo_gbrv_ag.local_PP()
v_gbrv_ag = pseudo_gbrv_ag.readpp.pp['Ag'].v

pseudo_ngbrv_ag = LocalPseudo(grid = grid, ions=ions_ag, PP_list=PP_list_ngbrv_ag)
pseudo_ngbrv_ag.local_PP()
v_ngbrv_ag = pseudo_ngbrv_ag.readpp.pp['Ag'].v
# Out:
# setting key: Ag -> /projectsn/mp1009_1/Valeria/NLPP/PP/ag_lda_v1.4.uspp.F.UPF
# setting key: Ag -> /projectsn/mp1009_1/Valeria/NLPP/NPP_0.2//Ag_gbrv_new.psp8

# %%
core_density_gbrv = pseudo_gbrv_ag.readpp.pp['Ag'].core_density
v_gbrv = pseudo_gbrv_ag.readpp.pp['Ag'].v
r_gbrv = pseudo_gbrv_ag.readpp.pp['Ag'].r
r_core = pseudo_gbrv_ag.readpp.pp['Ag'].core_density_grid

# %%
r0 = 0.7
core_density = construct_core_density_smooth(r=r, r_pc=r0, r_core=r_gbrv, rho_core_array=rho_core_array)

# %%
plt.plot(r, rho * 4 * pi * r**2, label='Total AE ρ(r)')
plt.plot(r,rho*g*4*pi*r**2,label="greater")

plt.plot(r, rho_core_array, label='Core ρ_core(r)', linestyle='--')
plt.axvline(rc, color='k', linestyle=':', label='rc')
plt.xlabel("r (a.u.)")
plt.ylabel("ρ(r)")
plt.legend()
plt.grid(True)
plt.title("AE and Smoothed Core Density")
plt.xlim(-0.010,3)
# # plt.show()

plt.plot(r_core, core_density)
plt.xlim(0,4)
# Out:
# (0.0, 4.0)

# %%
r_safe = r_gbrv.copy()
r_safe[r_safe == 0] = 1e-8

# %% [markdown]
# ### Build gaussians with different strenght (hight)

# %%
core_1 = core_density/4/np.pi/r_safe**2
core_2 = core_density/4/np.pi/r_safe**2 /2
core_4 = core_density/4/np.pi/r_safe**2 /4
core_8 = core_density/4/np.pi/r_safe**2 /8

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(15,4))
axs.plot(r_gbrv, core_1.ravel(), 'r')
axs.plot(r_gbrv, core_2.ravel(), 'g')
axs.plot(r_gbrv, core_4.ravel(), color='orange')
axs.plot(r_gbrv, core_8.ravel(), color='purple')

axs.plot(r_gbrv, core_density_gbrv.ravel(), 'b.')

# axs[1].plot(r_ngbrv, (v_ngbrv_ag).ravel(), 'r')
# axs[1].plot(r_gbrv, v_gbrv_ag.ravel(), 'b.')
axs.set_xlim(-0.01,3)
# axs[1].set_xlim(0.0,4)
# Out:
# (-0.01, 3.0)

# %%
path_ngbrv = '/projectsn/mp1009_1/Valeria/NLPP/NPP_0.2/'
PP_list_ngbrv_ag = {'Ag': path_ngbrv + '/Ag_gbrv_new.psp8'}

key = 'Ag'
r = pseudo_ngbrv_ag.readpp.pp[key].r
vl = pseudo_ngbrv_ag.readpp.pp[key].v
zval = pseudo_ngbrv_ag.zval[key]

from dftpy.functional.pseudo.psp import PSP
engine = PSP(None)
engine.r = r
engine.v = vl
engine.info['atomicnum'] = 27
engine.info['fchrg'] = 1.0
engine.info['mmax'] = len(r)
engine._zval = zval
engine._core_density_grid = r

# %%
engine._core_density = core_1 *4*np.pi#* 4* np.pi
engine.write('Ag_AE_1_gbrv.psp8')

# %%
engine._core_density = core_2 *4*np.pi#* 4* np.pi
engine.write('Ag_AE_2_gbrv.psp8')

# %%
engine._core_density = core_4 *4*np.pi#* 4* np.pi
engine.write('Ag_AE_4_gbrv.psp8')

# %%
engine._core_density = core_8 *4*np.pi#* 4* np.pi
engine.write('Ag_AE_8_gbrv.psp8')

# %%
path_ngbrv = './'
PP_list_ngbrv_1 = {'Ag': path_ngbrv + '/Ag_AE_1_gbrv.psp8'}
PP_list_ngbrv_2 = {'Ag': path_ngbrv + '/Ag_AE_2_gbrv.psp8'}
PP_list_ngbrv_4 = {'Ag': path_ngbrv + '/Ag_AE_4_gbrv.psp8'}
PP_list_ngbrv_8 = {'Ag': path_ngbrv + '/Ag_AE_8_gbrv.psp8'}

# %%
pseudo_ngbrv_1 = LocalPseudo(grid = grid, ions=ions_ag, PP_list=PP_list_ngbrv_1)
pseudo_ngbrv_2 = LocalPseudo(grid = grid, ions=ions_ag, PP_list=PP_list_ngbrv_2)
pseudo_ngbrv_4 = LocalPseudo(grid = grid, ions=ions_ag, PP_list=PP_list_ngbrv_4)
pseudo_ngbrv_8 = LocalPseudo(grid = grid, ions=ions_ag, PP_list=PP_list_ngbrv_8)

pseudo_ngbrv_1.local_PP()
pseudo_ngbrv_2.local_PP()
pseudo_ngbrv_4.local_PP()
pseudo_ngbrv_8.local_PP()

core_density_1 = pseudo_ngbrv_1.core_density
core_density_2 = pseudo_ngbrv_2.core_density
core_density_4 = pseudo_ngbrv_4.core_density
core_density_8 = pseudo_ngbrv_8.core_density

v_ngbrv_1 = pseudo_ngbrv_1.readpp.pp['Ag'].v
v_ngbrv_2 = pseudo_ngbrv_2.readpp.pp['Ag'].v
v_ngbrv_4 = pseudo_ngbrv_4.readpp.pp['Ag'].v
v_ngbrv_8 = pseudo_ngbrv_8.readpp.pp['Ag'].v

core_density_ngbrv_1 = pseudo_ngbrv_1.readpp.pp['Ag'].core_density
core_density_ngbrv_2 = pseudo_ngbrv_2.readpp.pp['Ag'].core_density
core_density_ngbrv_4 = pseudo_ngbrv_4.readpp.pp['Ag'].core_density
core_density_ngbrv_8 = pseudo_ngbrv_8.readpp.pp['Ag'].core_density

r_ngbrv = pseudo_ngbrv_ag.readpp.pp['Ag'].r
# r_core = pseudo_ngbrv_ag.readpp.pp['Ag'].core_density_grid
# Out:
# setting key: Ag -> .//Ag_AE_1_gbrv.psp8
# setting key: Ag -> .//Ag_AE_2_gbrv.psp8
# setting key: Ag -> .//Ag_AE_4_gbrv.psp8
# setting key: Ag -> .//Ag_AE_8_gbrv.psp8
# Warning 0.0019244498071592695
# Warning 0.0009622249036919051
# Warning 0.00048111245183313065
# Warning 0.00024055622590732752

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(9,5))
axs[0].plot(r, (core_density_ngbrv_1).ravel(), 'r')
axs[0].plot(r, (core_density_ngbrv_2).ravel(), 'g')
axs[0].plot(r, (core_density_ngbrv_4).ravel(), color='orange')
axs[0].plot(r, (core_density_ngbrv_8).ravel(), color='purple')

axs[0].plot(r_gbrv, core_density_gbrv.ravel(), 'b.')

axs[1].plot(r_ngbrv, (v_ngbrv_ag).ravel(), 'r')
axs[1].plot(r_gbrv, v_gbrv_ag.ravel(), 'b.')
axs[0].set_xlim(0.0,4)
axs[1].set_xlim(0.0,4)
# Out:
# (0.0, 4.0)

# %%
core_density_gbrv = pseudo_gbrv_ag.core_density

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10,5))
axs[0,0].plot(core_density_gbrv.ravel())

z_slice = 3
im1 = axs[0,1].imshow(core_density_gbrv[:, :, z_slice], origin='lower', cmap='viridis')
fig.colorbar(im1, ax=axs[0,1], orientation='vertical')

axs[0,1].set_xlabel("x")
axs[0,1].set_ylabel("y")

axs[0,0].set_ylabel("GBRV core density")

axs[1,0].set_ylabel("Build the core density")

axs[1,0].plot(core_density_1.ravel())
axs[1,0].plot(core_density_2.ravel())
axs[1,0].plot(core_density_4.ravel())
axs[1,0].plot(core_density_8.ravel())

im2=axs[1,1].imshow(core_density_1[:, :, z_slice], origin='lower', cmap='viridis')
fig.colorbar(im2, ax=axs[1,1], orientation='vertical')

axs[1,1].set_xlabel("x")
axs[1,1].set_ylabel("y")

plt.show()

# %% [markdown]
# ### Analisys of vlines_core

# %%
from scipy.interpolate import splrep, splev
from dftpy.math_utils import quartic_interpolation
def calc_vlines(pseudo, gps, vps, interps):
    vlines = {}
    reciprocal_grid = pseudo.grid.get_reciprocal()
    q = reciprocal_grid.q
    vloc = np.empty_like(q)
    for key in sorted(interps):
        interp = interps[key]
        if interp is None :
            vlines[key] = None
            continue
        vloc[:] = 0.0
        mask = q < gps[key][-1]
        qmask = q[mask]
        if len(qmask)>0 :
            vloc[mask] = splev(qmask, interp, der=0)
        # quartic interpolation for small q
        # -----------------------------------------------------------------------
        mask = q < gps[key][1]
        vp = vps[key]
        dp = gps[key][1] - gps[key][0]
        f = [vp[2], vp[1], vp[0], vp[1], vp[2]]
        dx = q[mask] / dp
        vloc[mask] = quartic_interpolation(f, dx)
        # -----------------------------------------------------------------------
        vlines[key] = vloc.copy()
    return vlines

# %%
vlines = calc_vlines(pseudo_ngbrv_ag, pseudo_ngbrv_ag.readpp._core_density_grid, pseudo_ngbrv_ag.readpp._core_density, pseudo_ngbrv_ag.vloc_interp_core)

# %% [markdown]
# ## Analysis in reciprocal space

# %%
import numpy as np
from dftpy.functional import TotalFunctional
from dftpy.optimization import Optimization
from copy import deepcopy

def compute_numerical_forces(ions, energy_evaluator, dr=1e-4):
    n_atoms = ions.nat
    forces = np.zeros((n_atoms, 3))
    positions0 = ions.positions.copy()

    for i in range(n_atoms):
        for j in range(3):
            ions_plus = deepcopy(ions)
            ions_plus.positions[i, j] += dr
            PSEUDO = LocalPseudo(grid = grid, ions=ions_plus, PP_list=PP_list_ngbrv_ag)
            eval_plus = TotalFunctional(KE=energy_evaluator.KE,
                                         XC=energy_evaluator.XC,
                                         HARTREE=energy_evaluator.HARTREE,
                                         PSEUDO=PSEUDO)
            eval_plus.ions = ions_plus
            rho_ini = DirectField(grid=grid)
            rho_ini[:] = ions_plus.get_ncharges()/ions_plus.cell.volume
            opt = Optimization(EnergyEvaluator=evaluator, optimization_options = opt_options,
                   optimization_method = 'CG')
            rho_plus = opt.optimize_rho(guess_rho=rho_ini)
            E_plus = eval_plus.Energy(rho_plus)
            
            ions_minus = deepcopy(ions)
            ions_minus.positions[i, j] -= dr
            PSEUDO = LocalPseudo(grid = grid, ions=ions_minus, PP_list=PP_list_ngbrv_ag)
            eval_minus = TotalFunctional(KE=energy_evaluator.KE,
                                          XC=energy_evaluator.XC,
                                          HARTREE=energy_evaluator.HARTREE,
                                          PSEUDO=PSEUDO)
            eval_minus.ions = ions_minus
            rho_ini = DirectField(grid=grid)
            rho_ini[:] = ions_minus.get_ncharges()/ions_minus.cell.volume
            opt = Optimization(EnergyEvaluator=evaluator, optimization_options = opt_options,
                   optimization_method = 'CG')
            rho_minus = opt.optimize_rho(guess_rho=rho_ini)
            E_minus = eval_minus.Energy(rho_minus)
            E_minus = eval_minus.Energy(rho_minus)

            forces[i, j] = -(E_plus - E_minus) / (2 * dr)

    ions.positions[:] = positions0
    return forces

def calc_force_cc(potential = None, rhod = None, rhov=None, ions = None):
    """Calculate the correction forces

    Parameters
    ----------
    potential : field
        Potential in real space.
    rhod :
        density of each element in reciprocal space
    """
    #
    # if rhod is None : rhod = self.vlines_core
    if ions is None : ions = ions
    grid = potential.grid
    #
    reciprocal_grid = grid.get_reciprocal()
    forces = np.zeros((ions.nat, 3))
    mask = reciprocal_grid.mask
    g = reciprocal_grid.g
    rhovg = rhov.fft()
    if potential.rank == 2 : potential = 0.5*(potential[0]+potential[1])
    potg = potential.fft()

    for key in sorted(ions.zval):
            rhocg = rhod
            if rhocg is None : continue
            for i in range(ions.nat):
                if ions.symbols[i] == key:
                    strf = ions.istrf(reciprocal_grid, i)
                    den = (potg[mask] * rhocg[mask] * strf[mask]).imag
                    for j in range(3):
                        forces[i, j] = np.einsum("i, i->", g[j][mask], den)
    forces *= - 2.0 / grid.volume ## Should be negative
    return forces

# %%
def get_energy(KE, XC, ions, PSEUDO):
    rho_ini = DirectField(grid=grid)
    rho_ini[:] = ions.get_ncharges()/ions.cell.volume
    evaluator = TotalFunctional(KE=KE, XC=XC, HARTREE=HARTREE, PSEUDO=PSEUDO)
    opt = Optimization(EnergyEvaluator=evaluator, optimization_options = opt_options,
                       optimization_method = 'CG')
    rho = opt.optimize_rho(guess_rho=rho_ini)
    forces = evaluator.get_forces(rho=rho)
    forces_ewald = evaluator.ewald.forces
    v = KE(rho).potential
    return evaluator.Energy(rho=rho, ions=ions), rho, forces, evaluator, forces_ewald

# %%
HARTREE = Functional(type='HARTREE')

# %%
from ase import Atoms
F_ngbrv_1 = []
F_ngbrv_2 = []
F_ngbrv_4 = []
F_ngbrv_8 = []
E_ngbrv_1 = []
E_ngbrv_2 = []
E_ngbrv_4 = []
E_ngbrv_8 = []

V = []

opt_options = {'econv' : 1e-10}
alats = [1.15, 1.2, 1.4, 1.6]#, 1.8, 2.0, 2.5, 3.0, 3.5, 4.0]#, 0.5, 0.7, 0.9, 1.0, 1.2, 1.4]
L = 10
for alat in alats:
    atoms = Atoms('Ag2', positions=[[L/2, L/2, L/2], [alat+L/2, L/2, L/2]])
    atoms.set_cell([L, L, L])
    ions = Ions.from_ase(atoms)
    grid = DirectGrid(lattice=ions.cell, ecut=40)
    print(grid.spacings[0], grid.nr)
    PSEUDO_1 = LocalPseudo(grid = grid, ions=ions, PP_list=PP_list_ngbrv_1)
    PSEUDO_2 = LocalPseudo(grid = grid, ions=ions, PP_list=PP_list_ngbrv_2)
    PSEUDO_4 = LocalPseudo(grid = grid, ions=ions, PP_list=PP_list_ngbrv_4)
    PSEUDO_8 = LocalPseudo(grid = grid, ions=ions, PP_list=PP_list_ngbrv_8)
    
    core_1 = PSEUDO_1.core_density
    core_2 = PSEUDO_2.core_density
    core_4 = PSEUDO_4.core_density
    core_8 = PSEUDO_8.core_density
        
    XC_1 = Functional(type='XC',name='LDA', core_density=core_1, pseudo=PSEUDO_1, libxc=False)
    KE_1 = Functional(type='KEDF', name='TFvW', y=0.2, core_density=core_1, pseudo=PSEUDO_1)
    
    XC_2 = Functional(type='XC',name='LDA', core_density=core_2, pseudo=PSEUDO_2, libxc=False)
    KE_2 = Functional(type='KEDF', name='TFvW', y=0.2, core_density=core_2, pseudo=PSEUDO_2)

    XC_4 = Functional(type='XC',name='LDA', core_density=core_4, pseudo=PSEUDO_4, libxc=False)
    KE_4 = Functional(type='KEDF', name='TFvW', y=0.2, core_density=core_4, pseudo=PSEUDO_4)  
    
    XC_8 = Functional(type='XC',name='LDA', core_density=core_8, pseudo=PSEUDO_8, libxc=False)
    KE_8 = Functional(type='KEDF', name='TFvW', y=0.2, core_density=core_8, pseudo=PSEUDO_8)

    
    ene_ngbrv_1, rho_1, forces_1, evaluator_1 , forces_ewald_1= get_energy(KE_1, XC_1, ions, PSEUDO_1)
    ene_ngbrv_2, rho_2, forces_2, evaluator_2 , forces_ewald_2= get_energy(KE_2, XC_2, ions, PSEUDO_2)
    ene_ngbrv_4, rho_4, forces_4, evaluator_4 , forces_ewald_4= get_energy(KE_4, XC_4, ions, PSEUDO_4)
    ene_ngbrv_8, rho_8, forces_8, evaluator_8 , forces_ewald_8= get_energy(KE_8, XC_8, ions, PSEUDO_8)

    
    # F_num.append(forces_num)
    F_ngbrv_1.append(forces_1)
    F_ngbrv_2.append(forces_2)
    F_ngbrv_4.append(forces_4)
    F_ngbrv_8.append(forces_8)
    
    E_ngbrv_1.append(ene_ngbrv_1)
    E_ngbrv_2.append(ene_ngbrv_2)
    E_ngbrv_4.append(ene_ngbrv_4)
    E_ngbrv_8.append(ene_ngbrv_8)
# Out:
# 0.34994928256239416 [54 54 54]
# setting key: Ag -> .//Ag_AE_1_gbrv.psp8
# setting key: Ag -> .//Ag_AE_2_gbrv.psp8
# setting key: Ag -> .//Ag_AE_4_gbrv.psp8
# setting key: Ag -> .//Ag_AE_8_gbrv.psp8
# Warning 0.04209845515380311
# Warning 0.0210492275768488
# Warning 0.010524613788441104
# Warning 0.005262306894224366
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       1.223234532187E+02      1.223235E+02    1.780333E+02    1       1       8.311272E-02
# 1       -1.530172672612E+02     -2.753407E+02   4.158124E+02    1       4       2.206032E-01
# 2       -2.004484432772E+02     -4.743118E+01   6.188919E+01    1       2       2.929840E-01
# 3       -2.057921625077E+02     -5.343719E+00   1.377064E+01    1       2       3.587615E-01
# 4       -2.068873995875E+02     -1.095237E+00   5.376425E+00    1       2       4.253581E-01
# 5       -2.073188708913E+02     -4.314713E-01   1.133627E+00    1       2       4.913981E-01
# 6       -2.074615702073E+02     -1.426993E-01   4.385751E-01    1       2       5.604265E-01
# 7       -2.075239438569E+02     -6.237365E-02   3.085688E-01    1       3       6.639962E-01
# 8       -2.075849334050E+02     -6.098955E-02   2.960896E-01    1       3       7.692394E-01
# 9       -2.076134808968E+02     -2.854749E-02   1.056174E-01    1       2       8.354189E-01
# 10      -2.076332420230E+02     -1.976113E-02   6.622918E-02    1       3       9.317501E-01
# 11      -2.076414471446E+02     -8.205122E-03   7.260681E-02    1       2       9.975297E-01
# 12      -2.076516888291E+02     -1.024168E-02   6.827288E-02    1       3       1.093757E+00
# 13      -2.076608826483E+02     -9.193819E-03   5.738433E-02    1       3       1.191014E+00
# 14      -2.076687540336E+02     -7.871385E-03   2.998200E-02    1       3       1.287178E+00
# 15      -2.076729806279E+02     -4.226594E-03   2.747734E-02    1       3       1.383362E+00
# 16      -2.076767188029E+02     -3.738175E-03   1.856731E-02    1       3       1.479979E+00
# 17      -2.076798248395E+02     -3.106037E-03   1.808622E-02    1       3       1.576053E+00
# 18      -2.076819699683E+02     -2.145129E-03   1.291590E-02    1       3       1.672849E+00
# 19      -2.076839276787E+02     -1.957710E-03   1.017661E-02    1       3       1.768932E+00
# 20      -2.076853763173E+02     -1.448639E-03   9.801218E-03    1       3       1.865894E+00
# 21      -2.076867930166E+02     -1.416699E-03   8.111820E-03    1       3       1.962322E+00
# 22      -2.076880210487E+02     -1.228032E-03   7.103737E-03    1       3       2.061052E+00
# 23      -2.076890443243E+02     -1.023276E-03   5.572393E-03    1       3       2.159020E+00
# 24      -2.076898293081E+02     -7.849838E-04   5.113388E-03    1       3       2.254157E+00
# 25      -2.076905948478E+02     -7.655397E-04   4.083917E-03    1       3       2.349694E+00
# 26      -2.076911548208E+02     -5.599730E-04   3.714888E-03    1       3       2.453560E+00
# 27      -2.076916518034E+02     -4.969826E-04   2.448375E-03    1       3       2.555605E+00
# 28      -2.076920095198E+02     -3.577165E-04   2.073625E-03    1       3       2.653229E+00
# 29      -2.076922836332E+02     -2.741134E-04   1.476967E-03    1       3       2.755155E+00
# 30      -2.076925020105E+02     -2.183772E-04   1.160664E-03    1       3       2.855453E+00
# 31      -2.076926501084E+02     -1.480980E-04   7.653412E-04    1       3       2.953202E+00
# 32      -2.076927587905E+02     -1.086820E-04   5.465938E-04    1       3       3.050292E+00
# 33      -2.076928272113E+02     -6.842087E-05   3.935925E-04    1       3       3.155177E+00
# 34      -2.076928826468E+02     -5.543542E-05   3.119332E-04    1       3       3.255999E+00
# 35      -2.076929225881E+02     -3.994134E-05   2.221323E-04    1       3       3.355739E+00
# 36      -2.076929531314E+02     -3.054328E-05   1.562175E-04    1       3       3.459303E+00
# 37      -2.076929754840E+02     -2.235259E-05   1.173190E-04    1       3       3.559087E+00
# 38      -2.076929927938E+02     -1.730986E-05   9.418832E-05    1       3       3.659832E+00
# 39      -2.076930064338E+02     -1.364002E-05   7.483405E-05    1       3       3.761727E+00
# 40      -2.076930170014E+02     -1.056754E-05   5.498931E-05    1       3       3.865477E+00
# 41      -2.076930244343E+02     -7.432929E-06   4.362178E-05    1       3       3.967816E+00
# 42      -2.076930301926E+02     -5.758309E-06   3.292322E-05    1       3       4.067764E+00
# 43      -2.076930349481E+02     -4.755488E-06   2.701268E-05    1       3       4.170851E+00
# 44      -2.076930386974E+02     -3.749242E-06   2.065319E-05    1       3       4.276761E+00
# 45      -2.076930416912E+02     -2.993854E-06   1.421294E-05    1       3       4.381864E+00
# 46      -2.076930438155E+02     -2.124312E-06   1.107529E-05    1       3       4.483985E+00
# 47      -2.076930455393E+02     -1.723780E-06   9.527851E-06    1       3       4.585407E+00
# 48      -2.076930470626E+02     -1.523316E-06   8.624108E-06    1       3       4.692702E+00
# 49      -2.076930483243E+02     -1.261711E-06   6.712107E-06    1       3       4.797066E+00
# 50      -2.076930492190E+02     -8.946928E-07   4.753802E-06    1       3       4.897487E+00
# 51      -2.076930499303E+02     -7.112940E-07   3.788120E-06    1       3       4.997256E+00
# 52      -2.076930505369E+02     -6.065329E-07   3.363531E-06    1       3       5.099501E+00
# 53      -2.076930510847E+02     -5.478788E-07   3.212748E-06    1       3       5.200431E+00
# 54      -2.076930515980E+02     -5.132758E-07   3.205844E-06    1       3       5.303187E+00
# 55      -2.076930521154E+02     -5.173579E-07   3.264731E-06    1       3       5.407820E+00
# 56      -2.076930526447E+02     -5.292994E-07   3.189711E-06    1       3       5.507211E+00
# 57      -2.076930531051E+02     -4.604010E-07   2.615248E-06    1       3       5.608881E+00
# 58      -2.076930534484E+02     -3.433109E-07   1.873799E-06    1       3       5.710316E+00
# 59      -2.076930536984E+02     -2.499773E-07   1.391894E-06    1       3       5.810083E+00
# 60      -2.076930538907E+02     -1.923496E-07   9.870879E-07    1       3       5.910468E+00
# 61      -2.076930540234E+02     -1.326820E-07   6.907392E-07    1       3       6.018778E+00
# 62      -2.076930541204E+02     -9.696998E-08   5.142958E-07    1       3       6.118473E+00
# 63      -2.076930541979E+02     -7.749941E-08   4.403536E-07    1       3       6.259014E+00
# 64      -2.076930542620E+02     -6.410772E-08   3.446638E-07    1       3       6.359410E+00
# 65      -2.076930543102E+02     -4.824608E-08   2.667825E-07    1       3       6.460642E+00
# 66      -2.076930543474E+02     -3.720112E-08   2.064733E-07    1       3       6.564077E+00
# 67      -2.076930543792E+02     -3.178025E-08   1.870666E-07    1       3       6.666445E+00
# 68      -2.076930544065E+02     -2.734578E-08   1.473574E-07    1       3       6.767194E+00
# 69      -2.076930544326E+02     -2.610636E-08   1.339633E-07    1       3       6.868682E+00
# 70      -2.076930544566E+02     -2.397053E-08   1.480581E-07    1       3       6.968878E+00
# 71      -2.076930544768E+02     -2.015355E-08   9.636676E-08    1       3       7.073520E+00
# 72      -2.076930544988E+02     -2.205769E-08   1.108097E-07    1       3       7.184009E+00
# 73      -2.076930545230E+02     -2.418517E-08   1.761952E-07    1       3       7.285414E+00
# 74      -2.076930545462E+02     -2.319268E-08   1.699615E-07    1       3       7.388755E+00
# 75      -2.076930545661E+02     -1.988798E-08   1.359247E-07    1       3       7.491049E+00
# 76      -2.076930545845E+02     -1.845569E-08   1.139610E-07    1       3       7.591485E+00
# 77      -2.076930546028E+02     -1.824736E-08   1.249883E-07    1       3       7.691072E+00
# 78      -2.076930546219E+02     -1.913475E-08   1.284374E-07    1       3       7.791436E+00
# 79      -2.076930546428E+02     -2.085937E-08   1.368484E-07    1       3       7.892888E+00
# 80      -2.076930546661E+02     -2.333366E-08   1.562619E-07    1       3       7.993395E+00
# 81      -2.076930546869E+02     -2.081168E-08   1.405585E-07    1       3       8.096509E+00
# 82      -2.076930547035E+02     -1.658378E-08   1.025432E-07    1       6       8.292425E+00
# 83      -2.076930547194E+02     -1.588018E-08   1.023806E-07    1       3       8.392272E+00
# 84      -2.076930547330E+02     -1.358131E-08   8.002368E-08    1       6       8.587339E+00
# 85      -2.076930547458E+02     -1.282433E-08   5.212976E-08    1       5       8.759263E+00
# 86      -2.076930547578E+02     -1.200999E-08   5.032656E-08    1       3       8.862390E+00
# 87      -2.076930547655E+02     -7.717517E-09   2.831414E-08    1       3       8.967069E+00
# 88      -2.076930547715E+02     -5.980780E-09   3.745465E-08    1       3       9.067025E+00
# 89      -2.076930547760E+02     -4.531671E-09   2.105365E-08    1       3       9.167716E+00
# 90      -2.076930547812E+02     -5.191112E-09   3.382200E-08    1       3       9.269033E+00
# 91      -2.076930547857E+02     -4.455330E-09   1.871633E-08    1       6       9.463947E+00
# 92      -2.076930547901E+02     -4.405081E-09   2.933219E-08    1       3       9.564688E+00
# 93      -2.076930547937E+02     -3.653781E-09   1.868920E-08    1       3       9.664319E+00
# 94      -2.076930547964E+02     -2.639013E-09   1.521805E-08    1       6       9.861053E+00
# 95      -2.076930547994E+02     -2.966260E-09   1.978759E-08    1       6       1.005259E+01
# 96      -2.076930548024E+02     -3.090861E-09   1.405056E-08    1       8       1.030721E+01
# 97      -2.076930548057E+02     -3.209493E-09   1.543232E-08    1       6       1.049959E+01
# 98      -2.076930548090E+02     -3.351033E-09   1.761911E-08    1       6       1.069414E+01
# 99      -2.076930548119E+02     -2.901686E-09   1.575639E-08    1       3       1.079464E+01
# 100     -2.076930548142E+02     -2.288061E-09   1.023645E-08    1       9       1.108021E+01
# 101     -2.076930548166E+02     -2.400327E-09   1.357758E-08    1       6       1.127521E+01
# 102     -2.076930548187E+02     -2.125489E-09   9.809135E-09    1       6       1.146875E+01
# 103     -2.076930548203E+02     -1.540855E-09   8.651923E-09    1       6       1.166325E+01
# 104     -2.076930548215E+02     -1.204398E-09   7.267452E-09    1       6       1.185595E+01
# 105     -2.076930548225E+02     -1.054957E-09   6.151697E-09    1       6       1.204900E+01
# 106     -2.076930548235E+02     -9.729320E-10   5.415407E-09    1       3       1.214823E+01
# 107     -2.076930548245E+02     -9.680434E-10   6.437006E-09    1       6       1.233884E+01
# 108     -2.076930548254E+02     -9.065957E-10   5.738194E-09    1       6       1.253187E+01
# 109     -2.076930548267E+02     -1.377884E-09   1.144968E-08    1       3       1.263233E+01
# 110     -2.076930548283E+02     -1.544663E-09   1.196187E-08    1       3       1.273135E+01
# 111     -2.076930548296E+02     -1.261014E-09   8.727578E-09    1       3       1.283036E+01
# 112     -2.076930548307E+02     -1.122885E-09   7.212120E-09    1       3       1.293093E+01
# 113     -2.076930548316E+02     -9.408723E-10   6.090255E-09    1       3       1.303453E+01
# 114     -2.076930548324E+02     -8.037659E-10   4.287325E-09    1       3       1.313759E+01
# 115     -2.076930548331E+02     -6.746745E-10   4.185913E-09    1       3       1.324151E+01
# 116     -2.076930548337E+02     -5.837251E-10   3.735966E-09    1       3       1.334480E+01
# 117     -2.076930548343E+02     -6.190248E-10   2.954135E-09    1       6       1.353867E+01
# 118     -2.076930548349E+02     -5.975949E-10   3.493282E-09    1       6       1.373221E+01
# 119     -2.076930548354E+02     -5.150582E-10   3.027063E-09    1       3       1.383861E+01
# 120     -2.076930548359E+02     -4.728236E-10   2.601088E-09    1       3       1.394461E+01
# 121     -2.076930548363E+02     -4.080221E-10   2.476126E-09    1       3       1.404409E+01
# 122     -2.076930548367E+02     -3.736318E-10   2.156024E-09    1       6       1.423584E+01
# 123     -2.076930548370E+02     -3.201421E-10   1.642709E-09    1       3       1.433331E+01
# 124     -2.076930548372E+02     -2.275442E-10   1.235035E-09    1       6       1.452290E+01
# 125     -2.076930548374E+02     -1.871854E-10   1.074859E-09    1       3       1.462067E+01
# 126     -2.076930548376E+02     -1.654143E-10   9.342148E-10    1       3       1.471931E+01
# 127     -2.076930548377E+02     -1.281251E-10   7.231803E-10    1       3       1.481726E+01
# 128     -2.076930548378E+02     -1.091394E-10   6.107813E-10    1       3       1.491589E+01
# 129     -2.076930548379E+02     -9.322321E-11   3.764852E-10    1       6       1.510699E+01
# 130     -2.076930548380E+02     -8.390089E-11   4.741001E-10    1       6       1.529482E+01
# 131     -2.076930548381E+02     -8.378720E-11   4.930735E-10    1       3       1.539301E+01
# 132     -2.076930548381E+02     -6.514256E-11   3.674470E-10    1       6       1.558365E+01
# 133     -2.076930548382E+02     -6.610890E-11   4.292892E-10    1       3       1.568117E+01
# 134     -2.076930548383E+02     -8.037659E-11   5.552782E-10    1       12      1.605495E+01
# 135     -2.076930548384E+02     -1.131752E-10   9.603329E-10    1       3       1.615256E+01
# 136     -2.076930548386E+02     -1.749072E-10   1.495974E-09    1       6       1.634178E+01
# 137     -2.076930548388E+02     -2.292495E-10   1.422439E-09    1       7       1.656391E+01
# 138     -2.076930548391E+02     -3.205969E-10   2.945154E-09    1       6       1.675391E+01
# 139     -2.076930548393E+02     -2.064553E-10   1.354766E-09    1       3       1.685239E+01
# 140     -2.076930548396E+02     -2.746106E-10   2.185219E-09    1       6       1.704147E+01
# 141     -2.076930548399E+02     -3.306582E-10   1.637583E-09    1       5       1.720081E+01
# 142     -2.076930548403E+02     -3.408900E-10   1.855285E-09    1       6       1.739153E+01
# 143     -2.076930548405E+02     -2.852403E-10   1.757537E-09    1       3       1.748925E+01
# 144     -2.076930548408E+02     -2.415277E-10   1.293097E-09    1       3       1.758751E+01
# 145     -2.076930548410E+02     -1.855938E-10   9.945292E-10    1       3       1.768599E+01
# 146     -2.076930548411E+02     -1.586500E-10   8.889177E-10    1       3       1.778359E+01
# 147     -2.076930548413E+02     -1.207354E-10   6.449506E-10    1       3       1.788166E+01
# 148     -2.076930548413E+02     -7.833023E-11   3.123535E-10    1       5       1.804039E+01
# 149     -2.076930548414E+02     -6.423306E-11   2.491293E-10    1       5       1.820041E+01
# 150     -2.076930548415E+02     -5.542233E-11   2.374304E-10    1       5       1.835953E+01
# 151     -2.076930548415E+02     -4.439471E-11   2.376104E-10    1       6       1.855043E+01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.08900410832378243
# Chemical potential (eV)  : -2.4219251493530414
# KE -6.162856801757023
# XC 0.561512248354431
# PSEUDO 73.87303647552133
# Ewald cosidered -75.93263166567569
# Not slpit consideres
# IF not split
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       7.628843930690E+01      7.628844E+01    1.824535E+02    1       1       7.583404E-02
# 1       -2.161931752552E+02     -2.924816E+02   4.965324E+02    1       4       2.032592E-01
# 2       -2.263042144367E+02     -1.011104E+01   1.050625E+03    1       1       2.390709E-01
# 3       -2.600468620893E+02     -3.374265E+01   7.623949E+01    1       2       3.057668E-01
# 4       -2.634573653312E+02     -3.410503E+00   5.023214E+01    1       2       3.724747E-01
# 5       -2.689650030939E+02     -5.507638E+00   1.744639E+01    1       3       4.700809E-01
# 6       -2.726072911552E+02     -3.642288E+00   2.238419E+01    1       3       5.672178E-01
# 7       -2.745637131349E+02     -1.956422E+00   1.075860E+01    1       3       6.645663E-01
# 8       -2.754323161758E+02     -8.686030E-01   4.685158E+00    1       3       7.617004E-01
# 9       -2.758527126550E+02     -4.203965E-01   4.314718E+00    1       2       8.286016E-01
# 10      -2.761622819698E+02     -3.095693E-01   1.905174E+00    1       3       9.272420E-01
# 11      -2.763275766148E+02     -1.652946E-01   7.156932E-01    1       3       1.027357E+00
# 12      -2.764111944464E+02     -8.361783E-02   4.250435E-01    1       3       1.127046E+00
# 13      -2.764617992447E+02     -5.060480E-02   3.695207E-01    1       2       1.195914E+00
# 14      -2.765050010028E+02     -4.320176E-02   1.820578E-01    1       2       1.264436E+00
# 15      -2.765262511441E+02     -2.125014E-02   1.192831E-01    1       3       1.365317E+00
# 16      -2.765439928597E+02     -1.774172E-02   8.398859E-02    1       3       1.465136E+00
# 17      -2.765554140781E+02     -1.142122E-02   7.829190E-02    1       3       1.565146E+00
# 18      -2.765648912868E+02     -9.477209E-03   5.229628E-02    1       3       1.667277E+00
# 19      -2.765727114214E+02     -7.820135E-03   4.145500E-02    1       3       1.768171E+00
# 20      -2.765776552135E+02     -4.943792E-03   2.718311E-02    1       3       1.868185E+00
# 21      -2.765814805358E+02     -3.825322E-03   1.662266E-02    1       3       1.967998E+00
# 22      -2.765840462796E+02     -2.565744E-03   1.765209E-02    1       3       2.067766E+00
# 23      -2.765865266072E+02     -2.480328E-03   1.162331E-02    1       3       2.169129E+00
# 24      -2.765881364752E+02     -1.609868E-03   1.058393E-02    1       3       2.274536E+00
# 25      -2.765897057226E+02     -1.569247E-03   9.541172E-03    1       3       2.374308E+00
# 26      -2.765909790117E+02     -1.273289E-03   7.467606E-03    1       3       2.474074E+00
# 27      -2.765919045929E+02     -9.255812E-04   5.253656E-03    1       3       2.573773E+00
# 28      -2.765926433782E+02     -7.387853E-04   4.094575E-03    1       3       2.675607E+00
# 29      -2.765932034023E+02     -5.600240E-04   3.529642E-03    1       3       2.774881E+00
# 30      -2.765937064739E+02     -5.030716E-04   2.637746E-03    1       3       2.874300E+00
# 31      -2.765940871225E+02     -3.806486E-04   2.268533E-03    1       3       2.973799E+00
# 32      -2.765944223434E+02     -3.352209E-04   1.766948E-03    1       3       3.073739E+00
# 33      -2.765946483183E+02     -2.259749E-04   1.281079E-03    1       3       3.175099E+00
# 34      -2.765948252875E+02     -1.769692E-04   1.138186E-03    1       3       3.274597E+00
# 35      -2.765949720382E+02     -1.467507E-04   8.164660E-04    1       3       3.374603E+00
# 36      -2.765950751363E+02     -1.030980E-04   5.972773E-04    1       3       3.474695E+00
# 37      -2.765951596360E+02     -8.449970E-05   4.811831E-04    1       3       3.576061E+00
# 38      -2.765952262563E+02     -6.662035E-05   3.691875E-04    1       3       3.675967E+00
# 39      -2.765952795549E+02     -5.329858E-05   2.847321E-04    1       3       3.785917E+00
# 40      -2.765953179288E+02     -3.837387E-05   2.115879E-04    1       3       3.890993E+00
# 41      -2.765953488351E+02     -3.090628E-05   1.777796E-04    1       3       3.994847E+00
# 42      -2.765953712390E+02     -2.240394E-05   1.286890E-04    1       3       4.098478E+00
# 43      -2.765953887077E+02     -1.746874E-05   1.095975E-04    1       3       4.200284E+00
# 44      -2.765954029824E+02     -1.427468E-05   8.038822E-05    1       3       4.300240E+00
# 45      -2.765954134754E+02     -1.049300E-05   5.960777E-05    1       3       4.401506E+00
# 46      -2.765954219004E+02     -8.425032E-06   4.715381E-05    1       3       4.504868E+00
# 47      -2.765954288143E+02     -6.913874E-06   3.766993E-05    1       3       4.604548E+00
# 48      -2.765954339844E+02     -5.170099E-06   2.807631E-05    1       3       4.704209E+00
# 49      -2.765954380628E+02     -4.078423E-06   2.199605E-05    1       3       4.804599E+00
# 50      -2.765954411299E+02     -3.067032E-06   1.783738E-05    1       3       4.905015E+00
# 51      -2.765954435988E+02     -2.468973E-06   1.457540E-05    1       3       5.005688E+00
# 52      -2.765954454221E+02     -1.823285E-06   1.083605E-05    1       3       5.105471E+00
# 53      -2.765954469144E+02     -1.492256E-06   8.801453E-06    1       3       5.205025E+00
# 54      -2.765954480550E+02     -1.140570E-06   6.361934E-06    1       3       5.304861E+00
# 55      -2.765954489582E+02     -9.032281E-07   4.948509E-06    1       3       5.406043E+00
# 56      -2.765954496945E+02     -7.362699E-07   3.863098E-06    1       3       5.505893E+00
# 57      -2.765954502508E+02     -5.563413E-07   2.914965E-06    1       3       5.605868E+00
# 58      -2.765954506763E+02     -4.255194E-07   2.300584E-06    1       3       5.705335E+00
# 59      -2.765954510132E+02     -3.369204E-07   1.736109E-06    1       3       5.806133E+00
# 60      -2.765954512661E+02     -2.528870E-07   1.274083E-06    1       3       5.907695E+00
# 61      -2.765954514451E+02     -1.790058E-07   9.390615E-07    1       3       6.008022E+00
# 62      -2.765954515759E+02     -1.307876E-07   7.804915E-07    1       3       6.107806E+00
# 63      -2.765954516785E+02     -1.026219E-07   6.022465E-07    1       3       6.207558E+00
# 64      -2.765954517552E+02     -7.661845E-08   4.757088E-07    1       3       6.308270E+00
# 65      -2.765954518226E+02     -6.744534E-08   3.727094E-07    1       3       6.408707E+00
# 66      -2.765954518754E+02     -5.282567E-08   2.874196E-07    1       3       6.508004E+00
# 67      -2.765954519176E+02     -4.216037E-08   2.371381E-07    1       3       6.608232E+00
# 68      -2.765954519528E+02     -3.520989E-08   1.953575E-07    1       3       6.709478E+00
# 69      -2.765954519822E+02     -2.936639E-08   1.629854E-07    1       3       6.810524E+00
# 70      -2.765954520076E+02     -2.548410E-08   1.388388E-07    1       3       6.911084E+00
# 71      -2.765954520300E+02     -2.236368E-08   1.164565E-07    1       3       7.010731E+00
# 72      -2.765954520508E+02     -2.075183E-08   1.194090E-07    1       3       7.110715E+00
# 73      -2.765954520691E+02     -1.834218E-08   8.830179E-08    1       3       7.211622E+00
# 74      -2.765954520852E+02     -1.610124E-08   6.989782E-08    1       3       7.311588E+00
# 75      -2.765954520985E+02     -1.333325E-08   7.484430E-08    1       3       7.411557E+00
# 76      -2.765954521101E+02     -1.157309E-08   6.778125E-08    1       6       7.605189E+00
# 77      -2.765954521196E+02     -9.502173E-09   6.079800E-08    1       3       7.706788E+00
# 78      -2.765954521273E+02     -7.725021E-09   4.017977E-08    1       6       7.901156E+00
# 79      -2.765954521327E+02     -5.369031E-09   3.069787E-08    1       3       8.001680E+00
# 80      -2.765954521373E+02     -4.619039E-09   2.650940E-08    1       3       8.104934E+00
# 81      -2.765954521413E+02     -3.986031E-09   1.744452E-08    1       5       8.268899E+00
# 82      -2.765954521452E+02     -3.876551E-09   2.259982E-08    1       3       8.369452E+00
# 83      -2.765954521491E+02     -3.904574E-09   2.051697E-08    1       6       8.564338E+00
# 84      -2.765954521533E+02     -4.159233E-09   2.420574E-08    1       3       8.664682E+00
# 85      -2.765954521571E+02     -3.855803E-09   1.972838E-08    1       3       8.765041E+00
# 86      -2.765954521601E+02     -3.023388E-09   1.916735E-08    1       3       8.865193E+00
# 87      -2.765954521630E+02     -2.887646E-09   1.290085E-08    1       6       9.061785E+00
# 88      -2.765954521656E+02     -2.621221E-09   1.681894E-08    1       6       9.256593E+00
# 89      -2.765954521687E+02     -3.016282E-09   1.977241E-08    1       6       9.451975E+00
# 90      -2.765954521715E+02     -2.805905E-09   1.741103E-08    1       3       9.552721E+00
# 91      -2.765954521737E+02     -2.275897E-09   1.164464E-08    1       3       9.653267E+00
# 92      -2.765954521752E+02     -1.434103E-09   6.345323E-09    1       3       9.753997E+00
# 93      -2.765954521761E+02     -8.828351E-10   4.806751E-09    1       3       9.855089E+00
# 94      -2.765954521768E+02     -7.460130E-10   4.439170E-09    1       3       9.957026E+00
# 95      -2.765954521774E+02     -6.467076E-10   3.993939E-09    1       3       1.005741E+01
# 96      -2.765954521780E+02     -5.243805E-10   3.176431E-09    1       6       1.025310E+01
# 97      -2.765954521784E+02     -4.010872E-10   2.238125E-09    1       3       1.035474E+01
# 98      -2.765954521787E+02     -3.204832E-10   1.770079E-09    1       6       1.054892E+01
# 99      -2.765954521790E+02     -2.669367E-10   1.194264E-09    1       8       1.080863E+01
# 100     -2.765954521792E+02     -2.215188E-10   9.465480E-10    1       5       1.097239E+01
# 101     -2.765954521794E+02     -2.297043E-10   1.444670E-09    1       3       1.107317E+01
# 102     -2.765954521796E+02     -2.161755E-10   1.342515E-09    1       6       1.126917E+01
# 103     -2.765954521798E+02     -1.736566E-10   1.052784E-09    1       6       1.146387E+01
# 104     -2.765954521799E+02     -1.394937E-10   8.426188E-10    1       3       1.156443E+01
# 105     -2.765954521801E+02     -1.207354E-10   5.808728E-10    1       9       1.185460E+01
# 106     -2.765954521802E+02     -1.219860E-10   7.408475E-10    1       3       1.195477E+01
# 107     -2.765954521803E+02     -1.181206E-10   6.559605E-10    1       3       1.205521E+01
# 108     -2.765954521804E+02     -9.521273E-11   5.332754E-10    1       3       1.215577E+01
# 109     -2.765954521805E+02     -8.338930E-11   4.906124E-10    1       3       1.225595E+01
# 110     -2.765954521806E+02     -7.878498E-11   4.855112E-10    1       3       1.235583E+01
# 111     -2.765954521806E+02     -6.821210E-11   4.432602E-10    1       3       1.246076E+01
# 112     -2.765954521807E+02     -6.269829E-11   3.632619E-10    1       3       1.256698E+01
# 113     -2.765954521807E+02     -4.916956E-11   2.986973E-10    1       3       1.267334E+01
# 114     -2.765954521808E+02     -3.853984E-11   2.440548E-10    1       3       1.278833E+01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.09214150310284772
# Chemical potential (eV)  : -2.5072980097970214
# KE -2.827352325119056
# XC 0.27222764924900417
# PSEUDO 75.16453516651299
# Ewald cosidered -75.93263166567569
# Not slpit consideres
# IF not split
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       6.201653813628E+01      6.201654E+01    1.850909E+02    1       1       8.039951E-02
# 1       -2.422697886834E+02     -3.042863E+02   5.584607E+02    1       4       2.165074E-01
# 2       -2.605734377833E+02     -1.830365E+01   8.528527E+02    1       1       2.540681E-01
# 3       -2.933015538322E+02     -3.272812E+01   6.774185E+01    1       3       3.550487E-01
# 4       -2.992981164609E+02     -5.996563E+00   1.808301E+01    1       2       4.243634E-01
# 5       -3.016998518967E+02     -2.401735E+00   1.616980E+01    1       3       5.246191E-01
# 6       -3.040053368873E+02     -2.305485E+00   8.902220E+00    1       3       6.295123E-01
# 7       -3.053537491187E+02     -1.348412E+00   5.186776E+00    1       3       7.308149E-01
# 8       -3.059224014361E+02     -5.686523E-01   2.812410E+00    1       3       8.395538E-01
# 9       -3.062400964203E+02     -3.176950E-01   1.658177E+00    1       3       9.995713E-01
# 10      -3.064241891612E+02     -1.840927E-01   9.917052E-01    1       3       1.112080E+00
# 11      -3.065310382270E+02     -1.068491E-01   5.024607E-01    1       3       1.215556E+00
# 12      -3.065942133244E+02     -6.317510E-02   3.681228E-01    1       3       1.317251E+00
# 13      -3.066321731796E+02     -3.795986E-02   2.023734E-01    1       3       1.419242E+00
# 14      -3.066602287081E+02     -2.805553E-02   1.246378E-01    1       3       1.519790E+00
# 15      -3.066765018457E+02     -1.627314E-02   9.169008E-02    1       3       1.622007E+00
# 16      -3.066885246826E+02     -1.202284E-02   6.720528E-02    1       3       1.723570E+00
# 17      -3.066976863107E+02     -9.161628E-03   5.069111E-02    1       3       1.826379E+00
# 18      -3.067039739332E+02     -6.287623E-03   4.172562E-02    1       3       1.926108E+00
# 19      -3.067091897098E+02     -5.215777E-03   3.136245E-02    1       3       2.028827E+00
# 20      -3.067133849522E+02     -4.195242E-03   2.354437E-02    1       3       2.132549E+00
# 21      -3.067168600398E+02     -3.475088E-03   1.823117E-02    1       3       2.235201E+00
# 22      -3.067193629150E+02     -2.502875E-03   1.467740E-02    1       3       2.336957E+00
# 23      -3.067215155924E+02     -2.152677E-03   1.168444E-02    1       3       2.437235E+00
# 24      -3.067231172111E+02     -1.601619E-03   9.484337E-03    1       3       2.540375E+00
# 25      -3.067243955160E+02     -1.278305E-03   8.428857E-03    1       3       2.641452E+00
# 26      -3.067253919133E+02     -9.963973E-04   6.410323E-03    1       3       2.742192E+00
# 27      -3.067262999889E+02     -9.080757E-04   4.883791E-03    1       3       2.842073E+00
# 28      -3.067270102071E+02     -7.102182E-04   3.914550E-03    1       3       2.944026E+00
# 29      -3.067275550492E+02     -5.448420E-04   3.229262E-03    1       3       3.047184E+00
# 30      -3.067280015678E+02     -4.465186E-04   2.443747E-03    1       3       3.149029E+00
# 31      -3.067283343398E+02     -3.327720E-04   2.015408E-03    1       3       3.249688E+00
# 32      -3.067286004275E+02     -2.660877E-04   1.554375E-03    1       3       3.350623E+00
# 33      -3.067287998055E+02     -1.993780E-04   1.243230E-03    1       3       3.453460E+00
# 34      -3.067289600753E+02     -1.602698E-04   9.934399E-04    1       3       3.555253E+00
# 35      -3.067290854322E+02     -1.253569E-04   7.197319E-04    1       3       3.656646E+00
# 36      -3.067291886147E+02     -1.031825E-04   5.441364E-04    1       3       3.754561E+00
# 37      -3.067292647709E+02     -7.615623E-05   4.111129E-04    1       3       3.855155E+00
# 38      -3.067293219867E+02     -5.721580E-05   3.317984E-04    1       3       3.957932E+00
# 39      -3.067293654843E+02     -4.349763E-05   2.585072E-04    1       3       4.061159E+00
# 40      -3.067293990993E+02     -3.361500E-05   2.011961E-04    1       3       4.162106E+00
# 41      -3.067294245340E+02     -2.543465E-05   1.547719E-04    1       3       4.263651E+00
# 42      -3.067294443673E+02     -1.983329E-05   1.193148E-04    1       3       4.367888E+00
# 43      -3.067294604462E+02     -1.607896E-05   8.999172E-05    1       3       4.469991E+00
# 44      -3.067294725137E+02     -1.206750E-05   7.032117E-05    1       3       4.571804E+00
# 45      -3.067294823691E+02     -9.855334E-06   5.368418E-05    1       3       4.670506E+00
# 46      -3.067294899391E+02     -7.570095E-06   4.103944E-05    1       3       4.771389E+00
# 47      -3.067294956956E+02     -5.756454E-06   3.331766E-05    1       3       4.873738E+00
# 48      -3.067294997097E+02     -4.014099E-06   2.657807E-05    1       3       4.975040E+00
# 49      -3.067295030105E+02     -3.300785E-06   1.922797E-05    1       3       5.077002E+00
# 50      -3.067295055875E+02     -2.576985E-06   1.425324E-05    1       3       5.175819E+00
# 51      -3.067295076154E+02     -2.027974E-06   1.080480E-05    1       3       5.279768E+00
# 52      -3.067295091435E+02     -1.528034E-06   8.272626E-06    1       3       5.380142E+00
# 53      -3.067295102778E+02     -1.134283E-06   6.898566E-06    1       3       5.480862E+00
# 54      -3.067295111542E+02     -8.764100E-07   5.207067E-06    1       3       5.580690E+00
# 55      -3.067295118447E+02     -6.905682E-07   4.173408E-06    1       3       5.681963E+00
# 56      -3.067295123908E+02     -5.460989E-07   3.242619E-06    1       3       5.786650E+00
# 57      -3.067295128169E+02     -4.260577E-07   2.612633E-06    1       3       5.887988E+00
# 58      -3.067295131638E+02     -3.468900E-07   1.954151E-06    1       3       5.990159E+00
# 59      -3.067295134409E+02     -2.771262E-07   1.526623E-06    1       3       6.089854E+00
# 60      -3.067295136605E+02     -2.195605E-07   1.225527E-06    1       3       6.191065E+00
# 61      -3.067295138298E+02     -1.693252E-07   1.000444E-06    1       3       6.291521E+00
# 62      -3.067295139645E+02     -1.347433E-07   8.426280E-07    1       3       6.392473E+00
# 63      -3.067295140696E+02     -1.050715E-07   6.749390E-07    1       3       6.493277E+00
# 64      -3.067295141595E+02     -8.987058E-08   5.120602E-07    1       3       6.592472E+00
# 65      -3.067295142322E+02     -7.271041E-08   3.889803E-07    1       3       6.696055E+00
# 66      -3.067295142856E+02     -5.338541E-08   2.935577E-07    1       3       6.796894E+00
# 67      -3.067295143250E+02     -3.946434E-08   2.189058E-07    1       3       6.897934E+00
# 68      -3.067295143550E+02     -2.994523E-08   1.749777E-07    1       3       6.998862E+00
# 69      -3.067295143780E+02     -2.302528E-08   1.361030E-07    1       3       7.102548E+00
# 70      -3.067295143958E+02     -1.778591E-08   1.038312E-07    1       3       7.203566E+00
# 71      -3.067295144104E+02     -1.456436E-08   8.267266E-08    1       3       7.304805E+00
# 72      -3.067295144223E+02     -1.189517E-08   7.031783E-08    1       3       7.404047E+00
# 73      -3.067295144325E+02     -1.026172E-08   5.722635E-08    1       3       7.505309E+00
# 74      -3.067295144412E+02     -8.684594E-09   4.663180E-08    1       3       7.608535E+00
# 75      -3.067295144491E+02     -7.882477E-09   4.859977E-08    1       3       7.709428E+00
# 76      -3.067295144556E+02     -6.520906E-09   4.097552E-08    1       3       7.810505E+00
# 77      -3.067295144610E+02     -5.401489E-09   2.763988E-08    1       5       7.971616E+00
# 78      -3.067295144663E+02     -5.319862E-09   3.490033E-08    1       3       8.076342E+00
# 79      -3.067295144714E+02     -5.069296E-09   3.238325E-08    1       6       8.274540E+00
# 80      -3.067295144759E+02     -4.480796E-09   2.680186E-08    1       6       8.472478E+00
# 81      -3.067295144800E+02     -4.163951E-09   2.455037E-08    1       6       8.667372E+00
# 82      -3.067295144836E+02     -3.597563E-09   2.258362E-08    1       3       8.769451E+00
# 83      -3.067295144866E+02     -2.963304E-09   1.852445E-08    1       6       8.965308E+00
# 84      -3.067295144890E+02     -2.386400E-09   1.517525E-08    1       3       9.066254E+00
# 85      -3.067295144910E+02     -2.027377E-09   1.290416E-08    1       6       9.262096E+00
# 86      -3.067295144928E+02     -1.828880E-09   1.011561E-08    1       3       9.363202E+00
# 87      -3.067295144943E+02     -1.486285E-09   7.575309E-09    1       6       9.559711E+00
# 88      -3.067295144956E+02     -1.289322E-09   7.059026E-09    1       6       9.762344E+00
# 89      -3.067295144968E+02     -1.164892E-09   6.763235E-09    1       6       9.961613E+00
# 90      -3.067295144977E+02     -9.339374E-10   5.584797E-09    1       6       1.015672E+01
# 91      -3.067295144985E+02     -7.790959E-10   5.171629E-09    1       6       1.035277E+01
# 92      -3.067295144992E+02     -7.460130E-10   4.378429E-09    1       3       1.045411E+01
# 93      -3.067295144999E+02     -6.343157E-10   3.250747E-09    1       6       1.064906E+01
# 94      -3.067295145004E+02     -5.522338E-10   3.334225E-09    1       3       1.075274E+01
# 95      -3.067295145009E+02     -4.862386E-10   3.012985E-09    1       3       1.085372E+01
# 96      -3.067295145013E+02     -4.174012E-10   2.311832E-09    1       6       1.104895E+01
# 97      -3.067295145017E+02     -3.502691E-10   1.713623E-09    1       6       1.124475E+01
# 98      -3.067295145020E+02     -3.246328E-10   2.144782E-09    1       3       1.134642E+01
# 99      -3.067295145023E+02     -2.927436E-10   1.740238E-09    1       3       1.144774E+01
# 100     -3.067295145025E+02     -2.323759E-10   1.437777E-09    1       3       1.154840E+01
# 101     -3.067295145027E+02     -1.946319E-10   8.861359E-10    1       9       1.183956E+01
# 102     -3.067295145029E+02     -1.537046E-10   7.225632E-10    1       6       1.203783E+01
# 103     -3.067295145030E+02     -1.248281E-10   7.616038E-10    1       3       1.213850E+01
# 104     -3.067295145031E+02     -1.002149E-10   6.680722E-10    1       3       1.224039E+01
# 105     -3.067295145032E+02     -9.407586E-11   6.555579E-10    1       3       1.234186E+01
# 106     -3.067295145033E+02     -9.282530E-11   5.737085E-10    1       3       1.244199E+01
# 107     -3.067295145034E+02     -7.679546E-11   4.821511E-10    1       3       1.254443E+01
# 108     -3.067295145034E+02     -7.082690E-11   3.894398E-10    1       6       1.289118E+01
# 109     -3.067295145035E+02     -5.951506E-11   3.653431E-10    1       6       1.316857E+01
# 110     -3.067295145036E+02     -5.348966E-11   3.687637E-10    1       3       1.328395E+01
# 111     -3.067295145036E+02     -5.047696E-11   3.820048E-10    1       3       1.340852E+01
# 112     -3.067295145037E+02     -5.564971E-11   4.019515E-10    1       6       1.360828E+01
# 113     -3.067295145037E+02     -6.178880E-11   3.866345E-10    1       6       1.380893E+01
# 114     -3.067295145038E+02     -6.383516E-11   4.015278E-10    1       3       1.390894E+01
# 115     -3.067295145039E+02     -6.758683E-11   4.446764E-10    1       6       1.410209E+01
# 116     -3.067295145039E+02     -6.298251E-11   4.817968E-10    1       3       1.420014E+01
# 117     -3.067295145040E+02     -6.900791E-11   5.197891E-10    1       3       1.429811E+01
# 118     -3.067295145041E+02     -7.850076E-11   5.346539E-10    1       12      1.469193E+01
# 119     -3.067295145042E+02     -8.645884E-11   5.843680E-10    1       3       1.478796E+01
# 120     -3.067295145043E+02     -1.014087E-10   7.415783E-10    1       3       1.488563E+01
# 121     -3.067295145044E+02     -1.185754E-10   9.171919E-10    1       3       1.498698E+01
# 122     -3.067295145045E+02     -1.353442E-10   1.021898E-09    1       3       1.508399E+01
# !!!ERROR : Line-Search Failed!!!
# !!!ERROR : Density Optimization NOT Converged  !!!
# Chemical potential (a.u.): -0.09410814177447036
# Chemical potential (eV)  : -2.560812973860994
# KE -1.3341381688207308
# XC 0.13312161475464337
# PSEUDO 75.84215391599149
# Ewald cosidered -75.93263166567569
# Not slpit consideres
# IF not split
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       5.756211090201E+01      5.756211E+01    1.865236E+02    1       1       8.541155E-02
# 1       -2.541743333872E+02     -3.117364E+02   5.978952E+02    1       4       2.190661E-01
# 2       -2.755139767680E+02     -2.133964E+01   7.736340E+02    1       1       2.550018E-01
# 3       -3.074370509100E+02     -3.192307E+01   7.358866E+01    1       3       3.540778E-01
# 4       -3.134006989576E+02     -5.963648E+00   1.917701E+01    1       2       4.224656E-01
# 5       -3.158473206908E+02     -2.446622E+00   1.653993E+01    1       3       5.209634E-01
# 6       -3.180647717132E+02     -2.217451E+00   9.586274E+00    1       3       6.531112E-01
# 7       -3.194320396821E+02     -1.367268E+00   4.664012E+00    1       3       7.517316E-01
# 8       -3.199838675542E+02     -5.518279E-01   2.846095E+00    1       3       8.499012E-01
# 9       -3.202663000221E+02     -2.824325E-01   1.182928E+00    1       2       9.178123E-01
# 10      -3.204374840002E+02     -1.711840E-01   9.979905E-01    1       3       1.016518E+00
# 11      -3.205461442146E+02     -1.086602E-01   6.139646E-01    1       3       1.116990E+00
# 12      -3.206123982428E+02     -6.625403E-02   3.608486E-01    1       3       1.213825E+00
# 13      -3.206539343054E+02     -4.153606E-02   2.114283E-01    1       3       1.311307E+00
# 14      -3.206822779751E+02     -2.834367E-02   1.714587E-01    1       3       1.410100E+00
# 15      -3.207040158480E+02     -2.173787E-02   1.298104E-01    1       3       1.510917E+00
# 16      -3.207187035833E+02     -1.468774E-02   7.519478E-02    1       3       1.610252E+00
# 17      -3.207292339893E+02     -1.053041E-02   6.344001E-02    1       3       1.707816E+00
# 18      -3.207364504365E+02     -7.216447E-03   3.323309E-02    1       2       1.776482E+00
# 19      -3.207417805299E+02     -5.330093E-03   2.956808E-02    1       3       1.875516E+00
# 20      -3.207458411283E+02     -4.060598E-03   2.804040E-02    1       3       1.975986E+00
# 21      -3.207490065900E+02     -3.165462E-03   1.867511E-02    1       3       2.077271E+00
# 22      -3.207519515196E+02     -2.944930E-03   1.586657E-02    1       3       2.174734E+00
# 23      -3.207543141788E+02     -2.362659E-03   1.668277E-02    1       3       2.272648E+00
# 24      -3.207564740245E+02     -2.159846E-03   1.365597E-02    1       3       2.372588E+00
# 25      -3.207579584438E+02     -1.484419E-03   8.960994E-03    1       3       2.473355E+00
# 26      -3.207592672574E+02     -1.308814E-03   7.222343E-03    1       3       2.572188E+00
# 27      -3.207603271471E+02     -1.059890E-03   5.924377E-03    1       3       2.669466E+00
# 28      -3.207611107365E+02     -7.835894E-04   4.936413E-03    1       3       2.768145E+00
# 29      -3.207617297164E+02     -6.189799E-04   4.127715E-03    1       3       2.870114E+00
# 30      -3.207622227313E+02     -4.930149E-04   3.282302E-03    1       3       2.969438E+00
# 31      -3.207626909508E+02     -4.682195E-04   2.577543E-03    1       3       3.067916E+00
# 32      -3.207630613153E+02     -3.703645E-04   1.970593E-03    1       3       3.166838E+00
# 33      -3.207632977907E+02     -2.364754E-04   1.547306E-03    1       3       3.266069E+00
# 34      -3.207634786195E+02     -1.808288E-04   1.100601E-03    1       3       3.366065E+00
# 35      -3.207636342087E+02     -1.555892E-04   9.340444E-04    1       3       3.463264E+00
# 36      -3.207637539789E+02     -1.197702E-04   6.295656E-04    1       3       3.560837E+00
# 37      -3.207638355406E+02     -8.156172E-05   5.755852E-04    1       3       3.659441E+00
# 38      -3.207639087110E+02     -7.317047E-05   4.553656E-04    1       3       3.760549E+00
# 39      -3.207639660966E+02     -5.738553E-05   3.365451E-04    1       3       3.860109E+00
# 40      -3.207640086837E+02     -4.258717E-05   2.445428E-04    1       3       3.957675E+00
# 41      -3.207640407141E+02     -3.203040E-05   1.740645E-04    1       3       4.055796E+00
# 42      -3.207640655169E+02     -2.480275E-05   1.523385E-04    1       3       4.153217E+00
# 43      -3.207640828870E+02     -1.737010E-05   1.137187E-04    1       3       4.253909E+00
# 44      -3.207640969277E+02     -1.404071E-05   8.909867E-05    1       3       4.353572E+00
# 45      -3.207641089282E+02     -1.200048E-05   6.444710E-05    1       3       4.452596E+00
# 46      -3.207641181829E+02     -9.254733E-06   5.594599E-05    1       3       4.549083E+00
# 47      -3.207641253818E+02     -7.198870E-06   4.387839E-05    1       3       4.649013E+00
# 48      -3.207641306851E+02     -5.303286E-06   3.151910E-05    1       3       4.748726E+00
# 49      -3.207641347315E+02     -4.046372E-06   2.572618E-05    1       3       4.847350E+00
# 50      -3.207641379204E+02     -3.188918E-06   1.931969E-05    1       3       4.945401E+00
# 51      -3.207641404458E+02     -2.525468E-06   1.517639E-05    1       3       5.043030E+00
# 52      -3.207641423874E+02     -1.941570E-06   1.118092E-05    1       3       5.143512E+00
# 53      -3.207641439101E+02     -1.522692E-06   9.596384E-06    1       3       5.241703E+00
# 54      -3.207641451129E+02     -1.202767E-06   7.107656E-06    1       3       5.340797E+00
# 55      -3.207641459964E+02     -8.835347E-07   5.506469E-06    1       3       5.437551E+00
# 56      -3.207641466958E+02     -6.993809E-07   4.024281E-06    1       3       5.537315E+00
# 57      -3.207641472136E+02     -5.178178E-07   3.016317E-06    1       3       5.634746E+00
# 58      -3.207641476085E+02     -3.948762E-07   2.523740E-06    1       3       5.732433E+00
# 59      -3.207641479071E+02     -2.985741E-07   1.854168E-06    1       3       5.830615E+00
# 60      -3.207641481544E+02     -2.473016E-07   1.382131E-06    1       3       5.929285E+00
# 61      -3.207641483450E+02     -1.906440E-07   1.062350E-06    1       3       6.030102E+00
# 62      -3.207641484875E+02     -1.425091E-07   9.197279E-07    1       3       6.126559E+00
# 63      -3.207641485988E+02     -1.112610E-07   6.775948E-07    1       3       6.225165E+00
# 64      -3.207641486802E+02     -8.142860E-08   4.989864E-07    1       3       6.324248E+00
# 65      -3.207641487477E+02     -6.745859E-08   3.995384E-07    1       3       6.425140E+00
# 66      -3.207641488008E+02     -5.310221E-08   3.086533E-07    1       3       6.524064E+00
# 67      -3.207641488443E+02     -4.354871E-08   2.520605E-07    1       3       6.622058E+00
# 68      -3.207641488765E+02     -3.221430E-08   2.068735E-07    1       3       6.719137E+00
# 69      -3.207641489027E+02     -2.619316E-08   1.690355E-07    1       3       6.818120E+00
# 70      -3.207641489253E+02     -2.258923E-08   1.367362E-07    1       3       6.918824E+00
# 71      -3.207641489446E+02     -1.931289E-08   1.202087E-07    1       3       7.018409E+00
# 72      -3.207641489612E+02     -1.662681E-08   1.073224E-07    1       3       7.117503E+00
# 73      -3.207641489769E+02     -1.567344E-08   8.705887E-08    1       3       7.215802E+00
# 74      -3.207641489928E+02     -1.589876E-08   8.871637E-08    1       3       7.318937E+00
# 75      -3.207641490095E+02     -1.671742E-08   1.273083E-07    1       3       7.418012E+00
# 76      -3.207641490309E+02     -2.138700E-08   1.644396E-07    1       6       7.610291E+00
# 77      -3.207641490557E+02     -2.481409E-08   1.768661E-07    1       3       7.710053E+00
# 78      -3.207641490768E+02     -2.105338E-08   1.511437E-07    1       3       7.812678E+00
# 79      -3.207641490928E+02     -1.597056E-08   1.005822E-07    1       3       7.911651E+00
# 80      -3.207641491054E+02     -1.268165E-08   7.528446E-08    1       7       8.132148E+00
# 81      -3.207641491155E+02     -1.009198E-08   6.332743E-08    1       3       8.232824E+00
# 82      -3.207641491234E+02     -7.864060E-09   5.310749E-08    1       3       8.331566E+00
# 83      -3.207641491306E+02     -7.182507E-09   4.252499E-08    1       6       8.523000E+00
# 84      -3.207641491369E+02     -6.334744E-09   3.312729E-08    1       3       8.624837E+00
# 85      -3.207641491426E+02     -5.680306E-09   2.906863E-08    1       3       8.725141E+00
# 86      -3.207641491478E+02     -5.161780E-09   3.126951E-08    1       3       8.824933E+00
# 87      -3.207641491514E+02     -3.638661E-09   1.712200E-08    1       3       8.923520E+00
# ...
# 54      -3.069958334739E+02     -7.849044E-07   4.489014E-06    1       3       4.974660E+00
# 55      -3.069958340832E+02     -6.092723E-07   3.221423E-06    1       3       5.068016E+00
# 56      -3.069958345411E+02     -4.579060E-07   2.488555E-06    1       3       5.161052E+00
# 57      -3.069958348967E+02     -3.556395E-07   1.977882E-06    1       3       5.256094E+00
# 58      -3.069958351681E+02     -2.713910E-07   1.506629E-06    1       3       5.350219E+00
# 59      -3.069958353803E+02     -2.121930E-07   1.110308E-06    1       3       5.443525E+00
# 60      -3.069958355315E+02     -1.511934E-07   8.452768E-07    1       3       5.537238E+00
# 61      -3.069958356472E+02     -1.157155E-07   6.437996E-07    1       3       5.634920E+00
# 62      -3.069958357361E+02     -8.886360E-08   4.798982E-07    1       3       5.729943E+00
# 63      -3.069958358040E+02     -6.790793E-08   3.597695E-07    1       3       5.823576E+00
# 64      -3.069958358549E+02     -5.090050E-08   2.731863E-07    1       3       5.917203E+00
# 65      -3.069958358940E+02     -3.914772E-08   2.212229E-07    1       3       6.012056E+00
# 66      -3.069958359250E+02     -3.091407E-08   1.759925E-07    1       3       6.108154E+00
# 67      -3.069958359496E+02     -2.460979E-08   1.414329E-07    1       3       6.201570E+00
# 68      -3.069958359697E+02     -2.017680E-08   1.149669E-07    1       3       6.295072E+00
# 69      -3.069958359866E+02     -1.684049E-08   9.252386E-08    1       3       6.388832E+00
# 70      -3.069958360003E+02     -1.372882E-08   7.376028E-08    1       3       6.483167E+00
# 71      -3.069958360107E+02     -1.034545E-08   5.854112E-08    1       3       6.578283E+00
# 72      -3.069958360189E+02     -8.209554E-09   4.527611E-08    1       3       6.672174E+00
# 73      -3.069958360257E+02     -6.817515E-09   3.847100E-08    1       3       6.766479E+00
# 74      -3.069958360314E+02     -5.705658E-09   3.125488E-08    1       3       6.860238E+00
# 75      -3.069958360361E+02     -4.696062E-09   2.785654E-08    1       3       6.954889E+00
# 76      -3.069958360400E+02     -3.916114E-09   1.934004E-08    1       3       7.049054E+00
# 77      -3.069958360435E+02     -3.509911E-09   1.738491E-08    1       3       7.142532E+00
# 78      -3.069958360462E+02     -2.711431E-09   1.611048E-08    1       3       7.236185E+00
# 79      -3.069958360485E+02     -2.268450E-09   1.005411E-08    1       3       7.330212E+00
# 80      -3.069958360505E+02     -1.963940E-09   1.162321E-08    1       3       7.425765E+00
# 81      -3.069958360521E+02     -1.625779E-09   7.706135E-09    1       3       7.519369E+00
# 82      -3.069958360535E+02     -1.457693E-09   8.745474E-09    1       3       7.613193E+00
# 83      -3.069958360548E+02     -1.264311E-09   7.714960E-09    1       6       7.796184E+00
# 84      -3.069958360560E+02     -1.224123E-09   5.347242E-09    1       6       7.978086E+00
# 85      -3.069958360570E+02     -1.012552E-09   6.440006E-09    1       3       8.071947E+00
# 86      -3.069958360580E+02     -9.761152E-10   4.192543E-09    1       6       8.255725E+00
# 87      -3.069958360588E+02     -7.769358E-10   4.727786E-09    1       3       8.349485E+00
# 88      -3.069958360596E+02     -7.621566E-10   4.943716E-09    1       3       8.443669E+00
# 89      -3.069958360604E+02     -8.158167E-10   5.215155E-09    1       6       8.626880E+00
# 90      -3.069958360611E+02     -7.591439E-10   4.692441E-09    1       3       8.721236E+00
# 91      -3.069958360619E+02     -7.659651E-10   4.780671E-09    1       3       8.814587E+00
# 92      -3.069958360626E+02     -6.571099E-10   3.916216E-09    1       3       8.908888E+00
# 93      -3.069958360632E+02     -6.078267E-10   3.640450E-09    1       3       9.003217E+00
# 94      -3.069958360637E+02     -5.207994E-10   2.880039E-09    1       3       9.099073E+00
# 95      -3.069958360641E+02     -4.379785E-10   2.624318E-09    1       6       9.281123E+00
# 96      -3.069958360645E+02     -3.743708E-10   2.195210E-09    1       6       9.464848E+00
# 97      -3.069958360648E+02     -3.347509E-10   2.095321E-09    1       3       9.559595E+00
# 98      -3.069958360651E+02     -2.882530E-10   1.381065E-09    1       6       9.741910E+00
# 99      -3.069958360654E+02     -2.493721E-10   1.391338E-09    1       3       9.836216E+00
# 100     -3.069958360656E+02     -2.175398E-10   1.253187E-09    1       6       1.002085E+01
# 101     -3.069958360658E+02     -1.888338E-10   8.777348E-10    1       5       1.017383E+01
# 102     -3.069958360659E+02     -1.488161E-10   7.818971E-10    1       6       1.035758E+01
# 103     -3.069958360660E+02     -1.258513E-10   7.945757E-10    1       3       1.045200E+01
# 104     -3.069958360662E+02     -1.044782E-10   4.987387E-10    1       8       1.069369E+01
# 105     -3.069958360662E+02     -8.930101E-11   3.552014E-10    1       6       1.087760E+01
# 106     -3.069958360663E+02     -7.014478E-11   3.923077E-10    1       6       1.105975E+01
# 107     -3.069958360664E+02     -6.343726E-11   3.152912E-10    1       6       1.124367E+01
# 108     -3.069958360664E+02     -6.076561E-11   3.214477E-10    1       6       1.142564E+01
# 109     -3.069958360665E+02     -4.587264E-11   2.772616E-10    1       3       1.152038E+01
# 110     -3.069958360665E+02     -4.064304E-11   2.434653E-10    1       3       1.161634E+01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.09414441662018164
# Chemical potential (eV)  : -2.561800062690618
# KE -0.12694115651843998
# XC 0.015870196977270476
# PSEUDO 38.45467833955861
# Ewald cosidered -38.75896672906419
# Not slpit consideres
# IF not split
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       1.138422369420E+01      1.138422E+01    1.710502E+02    1       1       7.268620E-02
# 1       -2.585458730387E+02     -2.699301E+02   4.573526E+02    1       4       1.962337E-01
# 2       -2.894015590428E+02     -3.085569E+01   3.148570E+02    1       1       2.308877E-01
# 3       -3.114568083343E+02     -2.205525E+01   4.159954E+01    1       2       2.950730E-01
# 4       -3.152282847419E+02     -3.771476E+00   1.214377E+01    1       2       3.592257E-01
# 5       -3.169520403493E+02     -1.723756E+00   7.335802E+00    1       3       4.556205E-01
# 6       -3.186582026355E+02     -1.706162E+00   7.026496E+00    1       3       5.486526E-01
# 7       -3.194548620570E+02     -7.966594E-01   4.173959E+00    1       3       6.422019E-01
# 8       -3.200225317288E+02     -5.676697E-01   1.945772E+00    1       2       7.071006E-01
# 9       -3.202585905866E+02     -2.360589E-01   1.439030E+00    1       3       8.000395E-01
# 10      -3.204313680485E+02     -1.727775E-01   9.214821E-01    1       3       8.955669E-01
# 11      -3.205463862275E+02     -1.150182E-01   4.605367E-01    1       3       1.004611E+00
# 12      -3.206061023046E+02     -5.971608E-02   3.561771E-01    1       3       1.098397E+00
# 13      -3.206467936602E+02     -4.069136E-02   2.101903E-01    1       3       1.197077E+00
# 14      -3.206743362614E+02     -2.754260E-02   1.565074E-01    1       3       1.299260E+00
# 15      -3.206960248300E+02     -2.168857E-02   1.045609E-01    1       3       1.394540E+00
# 16      -3.207086943926E+02     -1.266956E-02   7.132418E-02    1       3       1.488227E+00
# 17      -3.207183468073E+02     -9.652415E-03   6.458603E-02    1       3       1.582219E+00
# 18      -3.207262659691E+02     -7.919162E-03   4.228744E-02    1       3       1.675565E+00
# 19      -3.207323086237E+02     -6.042655E-03   3.812727E-02    1       3       1.771016E+00
# 20      -3.207368313680E+02     -4.522744E-03   2.458571E-02    1       3       1.864732E+00
# 21      -3.207406747643E+02     -3.843396E-03   2.042614E-02    1       3       1.958903E+00
# 22      -3.207438099398E+02     -3.135175E-03   1.698553E-02    1       3       2.053119E+00
# 23      -3.207461466717E+02     -2.336732E-03   1.241414E-02    1       3       2.149027E+00
# 24      -3.207480467914E+02     -1.900120E-03   1.063783E-02    1       3       2.243214E+00
# 25      -3.207494482912E+02     -1.401500E-03   8.578222E-03    1       3       2.336345E+00
# 26      -3.207507114065E+02     -1.263115E-03   7.424291E-03    1       3       2.430058E+00
# 27      -3.207516399830E+02     -9.285765E-04   5.607656E-03    1       3       2.523782E+00
# 28      -3.207524000062E+02     -7.600232E-04   4.540565E-03    1       3       2.619011E+00
# 29      -3.207530218202E+02     -6.218140E-04   3.674706E-03    1       3       2.712554E+00
# 30      -3.207535323111E+02     -5.104909E-04   2.751156E-03    1       3       2.805809E+00
# 31      -3.207539266263E+02     -3.943151E-04   2.201827E-03    1       3       2.900047E+00
# 32      -3.207542104893E+02     -2.838630E-04   1.674800E-03    1       3       2.995335E+00
# 33      -3.207544462332E+02     -2.357439E-04   1.428890E-03    1       3       3.090105E+00
# 34      -3.207546234324E+02     -1.771991E-04   1.052196E-03    1       3       3.182986E+00
# 35      -3.207547568584E+02     -1.334261E-04   8.111422E-04    1       3       3.276218E+00
# 36      -3.207548645819E+02     -1.077235E-04   6.067476E-04    1       3       3.369900E+00
# 37      -3.207549491981E+02     -8.461621E-05   4.688260E-04    1       3       3.465116E+00
# 38      -3.207550145109E+02     -6.531280E-05   3.474974E-04    1       3       3.559050E+00
# 39      -3.207550636966E+02     -4.918566E-05   2.573144E-04    1       3       3.652108E+00
# 40      -3.207551003273E+02     -3.663074E-05   2.028610E-04    1       3       3.745261E+00
# 41      -3.207551288930E+02     -2.856564E-05   1.511980E-04    1       3       3.839844E+00
# 42      -3.207551501092E+02     -2.121618E-05   1.231749E-04    1       3       3.934339E+00
# 43      -3.207551655543E+02     -1.544518E-05   9.193608E-05    1       3       4.027446E+00
# 44      -3.207551776962E+02     -1.214181E-05   7.148791E-05    1       3       4.120654E+00
# 45      -3.207551873426E+02     -9.646430E-06   5.547407E-05    1       3       4.214045E+00
# 46      -3.207551948239E+02     -7.481294E-06   4.100206E-05    1       3       4.309653E+00
# 47      -3.207552004286E+02     -5.604705E-06   3.293839E-05    1       3       4.403891E+00
# 48      -3.207552048250E+02     -4.396410E-06   2.429374E-05    1       3       4.496992E+00
# 49      -3.207552082745E+02     -3.449516E-06   1.894306E-05    1       3       4.590494E+00
# 50      -3.207552109001E+02     -2.625611E-06   1.458226E-05    1       3       4.685937E+00
# 51      -3.207552127707E+02     -1.870607E-06   1.198447E-05    1       3       4.779530E+00
# 52      -3.207552142366E+02     -1.465913E-06   9.047718E-06    1       3       4.872879E+00
# 53      -3.207552154373E+02     -1.200615E-06   6.549396E-06    1       3       4.966150E+00
# 54      -3.207552163422E+02     -9.049701E-07   4.927496E-06    1       3       5.059702E+00
# 55      -3.207552170307E+02     -6.885182E-07   3.638802E-06    1       3       5.155074E+00
# 56      -3.207552175532E+02     -5.224991E-07   2.845606E-06    1       3       5.248021E+00
# 57      -3.207552179450E+02     -3.917897E-07   2.134876E-06    1       3       5.341929E+00
# 58      -3.207552182455E+02     -3.005044E-07   1.598796E-06    1       3       5.436127E+00
# 59      -3.207552184745E+02     -2.289938E-07   1.239803E-06    1       3       5.531811E+00
# 60      -3.207552186469E+02     -1.723594E-07   9.927100E-07    1       3       5.625260E+00
# 61      -3.207552187774E+02     -1.305157E-07   7.972060E-07    1       3       5.718660E+00
# 62      -3.207552188756E+02     -9.819814E-08   5.855468E-07    1       3       5.812539E+00
# 63      -3.207552189544E+02     -7.878492E-08   4.533378E-07    1       3       5.908269E+00
# 64      -3.207552190147E+02     -6.032917E-08   3.410586E-07    1       3       6.003764E+00
# 65      -3.207552190597E+02     -4.500890E-08   2.434964E-07    1       3       6.097646E+00
# 66      -3.207552190932E+02     -3.347282E-08   1.823058E-07    1       3       6.193990E+00
# 67      -3.207552191183E+02     -2.506556E-08   1.440477E-07    1       3       6.289256E+00
# 68      -3.207552191379E+02     -1.964054E-08   1.179424E-07    1       3       6.384715E+00
# 69      -3.207552191532E+02     -1.524768E-08   9.147743E-08    1       3       6.479232E+00
# 70      -3.207552191656E+02     -1.249009E-08   7.355476E-08    1       3       6.573213E+00
# 71      -3.207552191758E+02     -1.017622E-08   5.704476E-08    1       3       6.667280E+00
# 72      -3.207552191841E+02     -8.244228E-09   4.454769E-08    1       3       6.761509E+00
# 73      -3.207552191904E+02     -6.344976E-09   3.624605E-08    1       3       6.856815E+00
# 74      -3.207552191955E+02     -5.126310E-09   2.842195E-08    1       3       6.950847E+00
# 75      -3.207552191997E+02     -4.182766E-09   2.282855E-08    1       3       7.044307E+00
# 76      -3.207552192029E+02     -3.159414E-09   1.915815E-08    1       3       7.138933E+00
# 77      -3.207552192053E+02     -2.407376E-09   1.475681E-08    1       3       7.234368E+00
# 78      -3.207552192073E+02     -2.019476E-09   1.176761E-08    1       3       7.328596E+00
# 79      -3.207552192090E+02     -1.697174E-09   9.825140E-09    1       3       7.422240E+00
# 80      -3.207552192104E+02     -1.417959E-09   8.075990E-09    1       3       7.515903E+00
# 81      -3.207552192116E+02     -1.166711E-09   6.542143E-09    1       3       7.610541E+00
# 82      -3.207552192125E+02     -9.473524E-10   4.185744E-09    1       3       7.706595E+00
# 83      -3.207552192133E+02     -7.724452E-10   4.165150E-09    1       3       7.800465E+00
# 84      -3.207552192139E+02     -5.952643E-10   2.992951E-09    1       5       7.953140E+00
# 85      -3.207552192144E+02     -4.819185E-10   2.794167E-09    1       3       8.047678E+00
# 86      -3.207552192148E+02     -3.855689E-10   2.490868E-09    1       3       8.142646E+00
# 87      -3.207552192151E+02     -3.248601E-10   1.564308E-09    1       5       8.294551E+00
# 88      -3.207552192154E+02     -2.696083E-10   1.708844E-09    1       3       8.388694E+00
# 89      -3.207552192156E+02     -2.314664E-10   1.374206E-09    1       3       8.484626E+00
# 90      -3.207552192158E+02     -1.895728E-10   1.133794E-09    1       3       8.579683E+00
# 91      -3.207552192160E+02     -1.693365E-10   1.001047E-09    1       6       8.761331E+00
# 92      -3.207552192161E+02     -1.411422E-10   8.404825E-10    1       3       8.854674E+00
# 93      -3.207552192162E+02     -1.126637E-10   7.118838E-10    1       3       8.950026E+00
# 94      -3.207552192163E+02     -1.028866E-10   6.617053E-10    1       6       9.131164E+00
# 95      -3.207552192164E+02     -8.327561E-11   5.082184E-10    1       3       9.225214E+00
# 96      -3.207552192165E+02     -7.594281E-11   4.398586E-10    1       3       9.321531E+00
# 97      -3.207552192165E+02     -6.627943E-11   3.663648E-10    1       6       9.503239E+00
# 98      -3.207552192166E+02     -5.314860E-11   3.150038E-10    1       9       9.775218E+00
# 99      -3.207552192166E+02     -4.757794E-11   2.727415E-10    1       9       1.004455E+01
# 100     -3.207552192167E+02     -4.109779E-11   2.374443E-10    1       9       1.031896E+01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): -0.09532884728741751
# Chemical potential (eV)  : -2.594030062795872
# KE -0.06027984867649506
# XC 0.007742040277700019
# PSEUDO 38.47943731722903
# Ewald cosidered -38.75896672906419
# Not slpit consideres
# IF not split

# %%
atom1_x_anl_1 = [F_ngbrv_1[0][0][0], F_ngbrv_1[1][0][0], F_ngbrv_1[2][0][0], F_ngbrv_1[3][0][0]]
atom1_x_anl_2 = [F_ngbrv_2[0][0][0], F_ngbrv_2[1][0][0], F_ngbrv_2[2][0][0], F_ngbrv_2[3][0][0]]
atom1_x_anl_4 = [F_ngbrv_4[0][0][0], F_ngbrv_4[1][0][0], F_ngbrv_4[2][0][0], F_ngbrv_4[3][0][0]]
atom1_x_anl_8 = [F_ngbrv_8[0][0][0], F_ngbrv_8[1][0][0], F_ngbrv_8[2][0][0], F_ngbrv_8[3][0][0]]

atom2_x_anl_1 = [F_ngbrv_1[0][1][0], F_ngbrv_1[1][1][0], F_ngbrv_1[2][1][0], F_ngbrv_1[3][1][0]]
atom2_x_anl_2 = [F_ngbrv_2[0][1][0], F_ngbrv_2[1][1][0], F_ngbrv_2[2][1][0], F_ngbrv_2[3][1][0]]
atom2_x_anl_4 = [F_ngbrv_4[0][1][0], F_ngbrv_4[1][1][0], F_ngbrv_4[2][1][0], F_ngbrv_4[3][1][0]]
atom2_x_anl_8 = [F_ngbrv_8[0][1][0], F_ngbrv_8[1][1][0], F_ngbrv_8[2][1][0], F_ngbrv_8[3][1][0]]

atom1_y_anl_1 = [F_ngbrv_1[0][0][1], F_ngbrv_1[1][0][1], F_ngbrv_1[2][0][1], F_ngbrv_1[3][0][1]]
atom1_y_anl_2 = [F_ngbrv_2[0][0][1], F_ngbrv_2[1][0][1], F_ngbrv_2[2][0][1], F_ngbrv_2[3][0][1]]
atom1_y_anl_4 = [F_ngbrv_4[0][0][1], F_ngbrv_4[1][0][1], F_ngbrv_4[2][0][1], F_ngbrv_4[3][0][1]]
atom1_y_anl_8 = [F_ngbrv_8[0][0][1], F_ngbrv_8[1][0][1], F_ngbrv_8[2][0][1], F_ngbrv_8[3][0][1]]

atom2_y_anl_1 = [F_ngbrv_1[0][1][1], F_ngbrv_1[1][1][1], F_ngbrv_1[2][1][1], F_ngbrv_1[3][1][1]]
atom2_y_anl_2 = [F_ngbrv_2[0][1][1], F_ngbrv_2[1][1][1], F_ngbrv_2[2][1][1], F_ngbrv_2[3][1][1]]
atom2_y_anl_4 = [F_ngbrv_4[0][1][1], F_ngbrv_4[1][1][1], F_ngbrv_4[2][1][1], F_ngbrv_4[3][1][1]]
atom2_y_anl_8 = [F_ngbrv_8[0][1][1], F_ngbrv_8[1][1][1], F_ngbrv_8[2][1][1], F_ngbrv_8[3][1][1]]

atom1_z_anl_1 = [F_ngbrv_1[0][0][2], F_ngbrv_1[1][0][2], F_ngbrv_1[2][0][2], F_ngbrv_1[3][0][2]]
atom1_z_anl_2 = [F_ngbrv_2[0][0][2], F_ngbrv_2[1][0][2], F_ngbrv_2[2][0][2], F_ngbrv_2[3][0][2]]
atom1_z_anl_4 = [F_ngbrv_4[0][0][2], F_ngbrv_4[1][0][2], F_ngbrv_4[2][0][2], F_ngbrv_4[3][0][2]]
atom1_z_anl_8 = [F_ngbrv_8[0][0][2], F_ngbrv_8[1][0][2], F_ngbrv_8[2][0][2], F_ngbrv_8[3][0][2]]

atom2_z_anl_1 = [F_ngbrv_1[0][1][2], F_ngbrv_1[1][1][2], F_ngbrv_1[2][1][2], F_ngbrv_1[3][1][2]]
atom2_z_anl_2 = [F_ngbrv_2[0][1][2], F_ngbrv_2[1][1][2], F_ngbrv_2[2][1][2], F_ngbrv_2[3][1][2]]
atom2_z_anl_4 = [F_ngbrv_4[0][1][2], F_ngbrv_4[1][1][2], F_ngbrv_4[2][1][2], F_ngbrv_4[3][1][2]]
atom2_z_anl_8 = [F_ngbrv_8[0][1][2], F_ngbrv_8[1][1][2], F_ngbrv_8[2][1][2], F_ngbrv_8[3][1][2]]

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(nrows=4, ncols=3, figsize=(15,7))

ax1 = plt.subplot(131) 
ax1.plot(r, (core_density_ngbrv_1).ravel(), 'r')
ax1.plot(r, (core_density_ngbrv_2).ravel(), 'g')
ax1.plot(r, (core_density_ngbrv_4).ravel(), color='orange')
ax1.plot(r, (core_density_ngbrv_8).ravel(), color='purple')
ax1.set_xlim(0,3)
ax1.set_xlabel('r(au)')
ax1.set_title('Core density')

# ax.set_xticks([])
axs[0,0].set_yticks([])
axs[1,0].set_yticks([])
axs[2,0].set_yticks([])
axs[3,0].set_yticks([])

axs[0,0].set_xticks([])
axs[1,0].set_xticks([])
axs[2,0].set_xticks([])
axs[3,0].set_xticks([])

axs[0,1].set_title('Energy vs distance')
axs[0,1].plot(alats, np.asarray(E_ngbrv_1).ravel(), 'r')
axs[1,1].plot(alats, np.asarray(E_ngbrv_2).ravel(), 'g')
axs[2,1].plot(alats, np.asarray(E_ngbrv_4).ravel(), color='orange')
axs[3,1].plot(alats, np.asarray(E_ngbrv_8).ravel(), color='purple')
axs[3,1].set_xlabel(r'r($\AA$)')

axs[0,2].set_title('Force vs distance')
axs[0,2].plot(alats, np.asarray(atom1_x_anl_1 ).ravel(), 'r')
axs[1,2].plot(alats, np.asarray(atom1_x_anl_2 ).ravel(), 'g')
axs[2,2].plot(alats, np.asarray(atom1_x_anl_4 ).ravel(), color='orange')
axs[3,2].plot(alats, np.asarray(atom1_x_anl_8 ).ravel(), color='purple')

axs[0,2].plot(alats, np.asarray(atom2_x_anl_1 ).ravel(), 'r')
axs[1,2].plot(alats, np.asarray(atom2_x_anl_2 ).ravel(), 'g')
axs[2,2].plot(alats, np.asarray(atom2_x_anl_4 ).ravel(), color='orange')
axs[3,2].plot(alats, np.asarray(atom2_x_anl_8 ).ravel(), color='purple')
axs[3,2].set_xlabel(r'r($\AA$)')
# Out:
# Text(0.5, 0, 'r($\\AA$)')
